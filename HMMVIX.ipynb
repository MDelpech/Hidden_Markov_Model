# %%
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd

# %%
file_path = "vix_data.csv"
vix_data = pd.read_csv(
    file_path,
    index_col=0,
    parse_dates=True,
    date_format="%Y-%m-%d"
)

# %%
vix_data.head()
# Out:
#                          Close                High                 Low  \
# Price
# Ticker                    ^VIX                ^VIX                ^VIX
# Date                       NaN                 NaN                 NaN
# 2004-01-02  18.219999313354492   18.68000030517578  17.540000915527344
# 2004-01-05  17.489999771118164  18.489999771118164  17.440000534057617
# 2004-01-06  16.729999542236328  17.670000076293945  16.190000534057617
#
#                           Open Volume
# Price
# Ticker                    ^VIX   ^VIX
# Date                       NaN    NaN
# 2004-01-02  17.959999084472656      0
# 2004-01-05  18.450000762939453      0
# 2004-01-06   17.65999984741211      0
